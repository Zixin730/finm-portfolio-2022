# %%
import numpy as np
from sklearn import linear_model

np.random.seed(6996)

# error term
epsilon_vec = np.random.normal(0, 1, 500).reshape(500,1)
# X_matrix or regressors or predictiors
X_mat = np.random.normal(0, 2, size = (500,500))
# Slope
slope_vec = np.random.uniform(1,5,500)
# Simulate Ys
Y_mat = 1 + np.cumsum(X_mat * slope_vec,axis=1)[:, 1:] + epsilon_vec
# each col of Y_mat representing one simulation vector: starting with 2 regressors, end with 500

# %%
reg = linear_model.LinearRegression().fit(X_mat[:, :40], Y_mat[:, 38])
reg.coef_
# Out:
# array([1.36638256, 1.71381778, 4.30857339, 4.02333555, 2.29722081,
#        3.27457633, 3.32678737, 4.56420342, 1.54614027, 4.79530723,
#        4.1302726 , 2.96639853, 4.17745142, 1.9722427 , 2.16563006,
#        3.83780114, 3.01453045, 2.87295669, 4.75014475, 1.37495175,
#        4.0565355 , 3.75476909, 3.2434535 , 1.16261201, 1.73704169,
#        3.86547065, 1.7702381 , 3.2059882 , 1.58854431, 2.97545719,
#        3.45923596, 1.85627963, 3.89199054, 3.67255803, 1.32996631,
#        3.45023662, 3.50167451, 3.10411985, 3.36174135, 1.18849295])

# %%
reg.intercept_ + np.sum(reg.coef_ * X_mat[:, :40], axis=1)
# Out:
# array([ -42.8642978 ,   32.44503649,  -31.37153592,   37.9277449 ,
#         -30.23949901,   49.39888178,   58.12567884,   24.54491598,
#         -79.66789723,  -14.32770044,   34.83517909,  -44.72665076,
#         -20.88576459,    6.69718321,   51.21947319,    1.52812135,
#         -12.31493513,  -21.03782468,  -62.92464129,   19.88679775,
#          55.38323218,    3.60483749,   29.1347789 ,  -64.24098329,
#         -25.29461712,  -22.42175373,  -45.03315524,  -40.03860808,
#          52.81518061,   34.38037207,  -31.8498408 ,   47.74003979,
#          66.0841758 ,  -31.02530645,  -17.46805509,   65.73578385,
#         -64.4078094 ,   37.44027923,   19.00383001,    8.53465184,
#          46.12191565,  -29.34174967,   42.05500464, -121.62981454,
#         -35.8347227 ,  -37.36259186,   56.84731484,   27.16373858,
#         -77.72380179,  -89.38424008,   93.94935164,   -2.80337371,
#          26.85049275,   52.34765947,   58.73644649,  -32.86716849,
#         -22.83305764,   34.04196034,  -11.27978195,  -39.51722842,
#          12.28196676,  -24.42779371,  -54.20683725,    1.98519234,
#          42.57205935,  -26.80208837,   -8.83448946,    4.6370106 ,
#           1.71671836,   21.12839059,  -32.45962984,  -49.48152778,
#          21.21134206,    0.16120623,   52.61332975,    5.2707016 ,
#         -41.2795267 ,   31.74646819,   27.78631157,    4.3757228 ,
#         -28.79363268,   55.54501095,  -45.39358182,   -2.96373182,
#          -1.39962814,  -28.62255883,  -43.32434828,  -17.72585787,
#          30.12878913,   11.16055918,  -31.35164072,  -22.49601519,
#         -42.66620041,   28.65140003,  -60.55605449,  -27.52536878,
#          50.72933486,  -42.98053397,  -30.29120138,   24.59056819,
#          24.40187845,   -0.48337402,  -21.21163136,   43.47255493,
#         -27.29086763,   33.86627781,   30.96770164,   37.29319022,
#          56.9939176 ,  -89.24331905,  -25.27946784,   25.86680633,
#          -4.36229725,   72.96193999,  -48.50202353,    8.5633485 ,
#          64.17551507,   14.37584861,   14.28120335,  -11.81986049,
#         -32.66935703,   -3.88299589,  -16.76436224,   29.86751564,
#           0.73218984,   20.35952887,   -4.37555546,   45.00672086,
#         -85.25264845,  -73.046879  ,  -24.10469803,   33.00337072,
#          34.52192824,    3.10755108,  -84.88928163,  -44.46289319,
#         -53.35889894,   32.43778005,  -31.2494421 ,  -33.07106672,
#           2.52695523,  -35.24063501,   66.65925164,  -24.05584533,
#           8.67774041,  -31.12795815, -119.0159776 ,  -43.25043667,
#           1.79659247,  -46.80019443,   52.00911934,   58.62612729,
#           6.50669229,   19.98571665,    1.36090072,  -27.08464628,
#          53.92546972,   38.20023186,    2.98411295,   -6.93262543,
#         -10.12945354,  -53.5158989 ,   47.83305581,   45.7043848 ,
#          20.387166  ,   79.79568854,   41.7537353 ,   51.78754514,
#         -24.19662647,   15.16835885,  -59.87567519,   -1.63278828,
#           5.47601633,  -48.55626814,   43.5497122 ,   22.42391183,
#          -6.15283597,  -21.71516204,   -8.10556361,   37.50001589,
#         -44.35165951,  -18.05927875,  -15.96758282,  -50.80271229,
#           4.00950562,  -24.46373454,   62.57278764,   94.94415434,
#          72.08252924,   -4.60076753,  -97.89276281,   26.85481339,
#         -41.27127599,   60.59030679,   24.47996426,   11.58981696,
#         -14.67814678,   47.12242377,   33.15127542,   -8.4419299 ,
#         -50.98771231,  -12.79407448,    3.82426785,  -30.89794388,
#          -6.12835251,  -36.84391924,   62.24700719,   37.93000756,
#          25.22222007,  -11.93971834,   -4.90143437,   33.64028584,
#          20.27910703,   57.19971939,   52.4430581 ,   -5.76214515,
#         -39.38510072,   69.12365298,  -66.54542044,   18.66921243,
#          26.55748655,  -44.05324316,  -46.22002009,   -5.60483021,
#         -15.15751259,   23.22625437,  -23.70520146,  -30.17366611,
#          11.4885315 ,   12.14248501,   46.16192966,  -57.94074753,
#         -26.96647573,   24.55383952,  -12.69825486,    2.39047103,
#         -39.52113099,  -37.58639573,   37.9408712 ,    8.2272472 ,
#        -107.87811867,  -18.90204907,   16.84964445,  -22.11253653,
#          60.72140207,  -52.27133315,   96.08792932,  -55.9042854 ,
#           8.29884532,  -13.23132867,  -18.96193904,   12.7880489 ,
#           5.93040726,    9.13284675,  -61.73378304,   33.78427619,
#         -13.23863487,   39.45798182,  -23.3673759 ,   58.85336074,
#           8.11689386,    3.98456768,   51.19029824,   -1.01465374,
#          55.45236824,   11.44804982,   27.31971472,    6.62316903,
#         -31.78460559,    3.10269348,    9.12275159,   37.09575708,
#         -17.44017553,  -96.9300013 ,   17.45338827,  -30.05848461,
#          -0.87796557,  -63.07889774,  -13.92830408,   26.9658763 ,
#           0.53199042,    0.24602794,   61.21316091,  -10.43159647,
#          26.32950401,   38.35492124,   62.30527596,  -65.41441948,
#          17.53160638,   67.65823855,   27.80500057,   -2.81821005,
#          50.07434547,  -36.27073721,    4.94550438,  -45.08606935,
#          -5.81072429,   66.75494338,   -7.63450366,   16.00048221,
#          52.6938435 ,    8.09528674,   35.04030373,    1.26842452,
#         -33.92595732,  -16.18212767,  -33.48495698,  -51.8326877 ,
#         -81.11756887,    3.93561665,   -5.41529356,   27.90785925,
#          37.99823571,   68.83743872,   52.21517549,  -15.36996592,
#         -10.47671087,  -15.25884643,    3.07553428,  -42.16533359,
#          -6.48354049,   59.16106181,  -61.35719648,   41.00375021,
#          78.83461689,  -12.14981409,   71.67539733,  -80.30446074,
#          51.45322923,    4.78188788,  -14.18058651,    6.12455341,
#         -26.15533944,    3.58998881,   32.84839418,  -33.50565473,
#          37.4221061 ,   34.86303028,  -19.93398512,   10.10124454,
#          12.64517091,   49.37307173,   27.10079184,   64.110469  ,
#         -59.03914914,    6.30659239,   14.16429829,   44.99085684,
#         -26.28469932,   57.20720778,   35.38774832,  -36.65181938,
#         -60.79066151,   74.17380081,  -43.85788616,   26.03866991,
#           3.17504117,  -51.41004178,   68.22442971,   81.73939238,
#         -14.51204439,   -9.37211806,  -10.08021541,    9.93374663,
#          43.09216166,   26.52666122,  -22.37199759,   66.80657244,
#          29.58731313,   -3.44962779,  -18.71426729,  -45.03815251,
#         -32.72447334,   15.13240361,   34.15267891,   61.47456813,
#          17.59135599,  -35.97997289,   -9.13050951,  -11.77236148,
#          33.75154528,  -51.50947802,  -53.92642632,    6.79328914,
#          58.55200243,   49.58309374,    4.92641438,  -73.92632467,
#           5.84335469,    4.71486701,   34.6099598 ,   34.54061893,
#          11.37566503,   20.450489  ,    6.58193055,  -46.10915189,
#         -41.17276918,  -47.07435531,   16.13488806,    8.13044686,
#         -32.06502521,   34.77202081,   44.02942976,  -62.33862911,
#           0.43419681,   -0.96825158,   39.30630802,    2.39512493,
#          40.28498836,  -96.02825347,  -17.84075804,  -93.40808629,
#          -3.03494298,   18.31275489,  -65.91448777,  -20.98599932,
#          58.31391407,  -15.7481123 ,  -27.90301866,   51.81947954,
#         -81.57646244,    3.34045702,    9.20527849,   29.45103473,
#          23.83834099,  -38.37258489,  -32.76079751,   48.87226842,
#         -24.81676963,  -61.45384946,  -81.92688461,   -8.77580918,
#         -56.35628857,  -24.38361107,  -40.61923821,   57.13028619,
#           3.16088489,   -2.41702966,   78.58347249,  -13.21266216,
#           7.06732843,   36.59320105,   76.76159323,  -34.50637769,
#          24.14187841,    3.21324042,  -25.82108545,  -32.95198643,
#          12.44048496,   27.3137021 ,    3.65386075,    2.00846126,
#          20.02624231,   11.38162551,   24.51170258,   23.08285888,
#         -54.25330789,  -32.78805855,  -45.35998793,    6.07973072,
#           2.66942623,  -56.13572223,  -29.40577129,  -25.10239204,
#          77.53992774,   81.95036988,  -65.87798792,  -63.54094338,
#          24.10269792,   -1.39807859,   -4.40646212,    4.57213098,
#         -16.25013949,   -7.75306756,   12.25666678,   58.58528065,
#           7.2683618 ,    7.40727848,  -20.64282726,  -53.20531887,
#           7.67832656,    8.98089535,  -26.21262536,  -12.89683927,
#         -61.56676672,  -41.4843008 ,  -31.93020936,   34.88279616,
#         -22.35088336,  -66.92914284,  -53.48841966,   42.06038826,
#          27.68030536,  -23.13527445,  -34.13124237,  -54.85054185,
#           7.814046  ,   32.56737468,    0.13431869,   27.84491248])

# %%
reg = linear_model.Ridge(alpha=0.5).fit(X_mat[:, :40], Y_mat[:, 38])
reg.alpha_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-1e876af64f31> in <module>
#       1 reg = linear_model.Ridge(alpha=0.5)
# ----> 2 reg.alpha_
#
# AttributeError: 'Ridge' object has no attribute 'alpha_'

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(reg, X_mat[:, :40], Y_mat[:, 38], cv=5)

# %%
N_feature = 10
split_ratio = 0.7
train_size = int(len(X_mat)*split_ratio)
X_train = X_mat[0:train_size, 0:N_feature]
Y_train = Y_mat[0:train_size, N_feature-2]
X_test = X_mat[train_size:, 0:N_feature]
Y_test = Y_mat[train_size:, N_feature-2]

# %%
alphas = [5**i for i in range(-8, 2)]
regr = linear_model.RidgeCV(alphas=alphas, cv=5).fit(X_train, Y_train)

# %%
alphas
# Out:
# [2.56e-06, 1.28e-05, 6.4e-05, 0.00032, 0.0016, 0.008, 0.04, 0.2, 1, 5]

# %%
regr.alpha_
# Out:
# 2.56e-06

# %%
reg = linear_model.LassoCV(cv=5).fit(X_train, Y_train)

# %%
reg.alpha_
# Out:
# 0.019252075773247068

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)


# Plot the data
#Define input array with angles from 60deg to 300deg converted to radians
x = np.array([i*np.pi/180 for i in range(60, 600, 1)])
np.random.seed(10)  # Setting seed for reproducability
y1 = np.sin(x) + np.random.normal(0, 0.15, len(x))
y2 = np.cos(x) + np.random.normal(0, 0.15, len(x))
data = pd.DataFrame(np.column_stack([x, y1, y2]), columns=['x', 'y1', 'y2'])

# Combine the data
y12 = np.append(y1, y2)
x12 = np.append(x, x)
y = np.append(np.repeat(1, len(x)), np.repeat(2, len(x)))
X = np.column_stack([x12, y12])

combined_data = pd.DataFrame(np.column_stack([X, y]), columns=['y', 'x', 'c'])
print(x12[1])
# Out:
# 1.064650843716541
